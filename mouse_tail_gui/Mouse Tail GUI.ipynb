# %%
import exiftool
import numpy as np
import os
import textwrap
import scipy.misc as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
et = exiftool.ExifTool()
et.start()

# %%
all_files = os.listdir('.')
jpegs = [x[:-4] for x in all_files if x[-4:] == '.jpg']

# %%
'exiftool.exe' in all_files
# Out:
# True

# %%
jpegs
# Out:
# ['FLIR0275', 'FLIR0276', 'FLIR0277', 'FLIR0278', 'FLIR0281']

# %%
for cur_jpeg in jpegs:
    cur_jpeg += '.jpg'
    byte_image = et.execute( b'-b', b'-RawThermalImage', cur_jpeg.encode('utf-8'))
    with open(cur_jpeg[:-4] + '.png', 'wb') as png_file:
        png_file.write(byte_image)

# %%
b = sm.imread(jpegs[0] + '.png')

# %%
plt.imshow(a.byteswap())

# %%
a = b.astype('int16')

# %%
b
# Out:
# array([[27440, 34352, 26416, ..., 32048, 30256, 39472],
#        [22576, 28976, 25648, ..., 43056, 40240, 31280],
#        [27696, 27184, 25136, ..., 37168, 34864, 37936],
#        ...,
#        [46896, 38192, 42800, ..., 35888, 28720, 26672],
#        [42800, 47664, 44336, ..., 36144, 26672, 24880],
#        [42544, 54576, 50992, ..., 32560, 25392, 34096]])
